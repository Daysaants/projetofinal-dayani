# %% [markdown]
# # Projeto Final:  Economia do Bem-Estar: Explorando a Saúde Mental em Contexto Global
#
# ## Contexto do Tema Escolhido:
# O projeto visa investigar a relação entre indicadores de saúde mental e variáveis socioeconômicas em diferentes países.
#
# ## Bases de Dados Escolhidas e Fontes:
#
# ### Base 1: Dados Relacionados à Saúde Mental
# - **Fonte:** [Our World in Data - Dealing with Anxiety & Depression Comparison](https://ourworldindata.org/grapher/dealing-with-anxiety-depression-comparison)
# - **Descrição:** Esta base de dados oferece informações relacionadas a questões de ansiedade, depressão e comportamentos associados, detalhando várias atividades, tratamentos e comportamentos em diferentes países ao longo do tempo.
#
# ### Base 2: Indicadores Socioeconômicos
# - **Fonte:** [Our World in Data - Antidepressants per Capita vs. GDP](https://ourworldindata.org/grapher/antidepressants-per-capita-vs-gdp)
# - **Descrição:** Esta base de dados compara o uso de antidepressivos per capita com o Produto Interno Bruto (PIB) per capita em diversos países, fornecendo insights sobre indicadores socioeconômicos e seu possível impacto na saúde mental.
#
# ## Objetivos do Projeto:
# - **Objetivo Geral:** Investigar a possível relação entre indicadores de saúde mental e fatores socioeconômicos em escala global.
# - **Objetivos Específicos:**
#   1. Explorar padrões e tendências nos dados de saúde mental e socioeconômicos.
#   2. Analisar correlações entre diferentes variáveis nos conjuntos de dados.
#   3. Identificar possíveis insights sobre como fatores socioeconômicos podem influenciar a saúde mental.
#
# ## Ferramentas Utilizadas:
# - **Linguagem de Programação:** Python
# - **Bibliotecas Principais:** Pandas, NumPy, Matplotlib, Seaborn
#
# ## Estrutura do Projeto:
# 1. **Importação e Limpeza dos Dados**
# 2. **Análise Exploratória dos Dados**
# 3. **Fusão e Análise Conjunta dos Dados**
# 4. **Exportação dos Dados Limpos**
# 5. **Conclusões e Descobertas**
#
# # Conclusão:
# Os dados analisados revelaram padrões interessantes na interseção entre indicadores de saúde mental e fatores socioeconômicos em uma perspectiva global. Enquanto as bases de dados investigadas oferecem insights detalhados sobre diferentes aspectos da saúde mental e seu contexto econômico, algumas observações se destacam:
#
# Variações Significativas: Observamos variações substanciais nos níveis de atividades relacionadas à saúde mental, comportamentos e tratamentos entre países. Essas discrepâncias podem refletir diferenças culturais, acesso a recursos de saúde e ênfase nas práticas de autocuidado em diferentes regiões.
#
# Correlações Emergentes: Embora não sejam conclusivas, foram identificadas algumas correlações interessantes entre indicadores socioeconômicos e dados de saúde mental. Por exemplo, o uso de antidepressivos per capita parece apresentar certa associação com o Produto Interno Bruto (PIB) per capita, sugerindo possíveis influências econômicas no tratamento de questões de saúde mental.
#
# Complexidade dos Fatores: É importante ressaltar a complexidade dos fatores que impactam a saúde mental. Embora os dados forneçam insights valiosos, é necessário um exame mais aprofundado e contextual para compreender completamente as nuances e determinantes por trás desses padrões observados.

# %%
import pandas as pd

# %%
data = pd.read_csv('base.csv')

# %%
data1 = pd.read_csv('base.csv')
data2 = pd.read_csv('antidepressants-per-capita-vs-gdp.csv')

# %%
print(data.head(6))
# Out:
#       Entity Code  Year  Religious/Spiritual Activities  \
# 0     Africa  NaN  2020                       63.715110
# 1    Albania  ALB  2020                       36.177600
# 2  Argentina  ARG  2020                       48.529037
# 3       Asia  NaN  2020                       40.451416
# 4  Australia  AUS  2020                       19.388412
# 5    Austria  AUT  2020                       33.628178
#
#    Improved Healthy Lifestyle  Changed Work Situation  \
# 0                   66.226456               47.928690
# 1                   67.716934               39.660843
# 2                   73.140980               52.189550
# 3                   72.909424               55.298290
# 4                   78.532410               55.528122
# 5                   82.493030               61.855377
#
#    Changed Personal Relationships  Talked to Friends or Family  \
# 0                       63.704567                    79.290146
# ...

# %%
print(data.describe())
# Out:
#          Year  Religious/Spiritual Activities  Improved Healthy Lifestyle  \
# count   113.0                      112.000000                  113.000000
# mean   2020.0                       42.886493                   70.848744
# std       0.0                       19.599188                   10.006569
# min    2020.0                        6.689826                   39.217323
# 25%    2020.0                       27.285091                   66.226456
# 50%    2020.0                       43.685280                   71.672745
# 75%    2020.0                       58.532954                   77.493960
# max    2020.0                       79.613980                   89.748720
#
#        Changed Work Situation  Changed Personal Relationships  \
# count              113.000000                      113.000000
# mean                49.718712                       60.424531
# std                 11.728922                       10.218758
# ...

# %%
data_sem_nulos = data.dropna()

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Entity                                113 non-null    object
#  1   Code                                  103 non-null    object
#  2   Year                                  113 non-null    int64
#  3   Religious/Spiritual Activities        112 non-null    float64
#  4   Improved Healthy Lifestyle            113 non-null    float64
#  5   Changed Work Situation                113 non-null    float64
#  6   Changed Personal Relationships        113 non-null    float64
#  7   Talked to Friends or Family           113 non-null    float64
#  8   Took Prescribed Medication            113 non-null    float64
#  9   Spent Time in Nature/Outdoors         113 non-null    float64
#  10  Talked to Mental Health Professional  113 non-null    float64
# ...

# %%
data1.columns = ['Entity', 'Code', 'Year', 'Religious/Spiritual Activities',
                'Improved Healthy Lifestyle', 'Changed Work Situation', 'Changed Personal Relationships',
                'Talked to Friends or Family', 'Took Prescribed Medication', 'Spent Time in Nature/Outdoors',
                'Talked to Mental Health Professional']

# %%
print(data.columns)
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Share - Question: mh8b - Engaged in religious/spiritual activities when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8e - Improved healthy lifestyle behaviors when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8f - Made a change to work situation when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8g - Made a change to personal relationships when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8c - Talked to friends or family when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8d - Took prescribed medication when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
# ...

# %%
data.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
print(data.columns)
# Out:
# Index(['Entity', 'Code', 'Year', 'Religious/Spiritual Activities',
#        'Improved Healthy Lifestyle', 'Changed Work Situation',
#        'Changed Personal Relationships', 'Talked to Friends or Family',
#        'Took Prescribed Medication', 'Spent Time in Nature/Outdoors',
#        'Talked to Mental Health Professional'],
#       dtype='object')

# %%
data2 = pd.read_csv('antidepressants-per-capita-vs-gdp.csv')

# %%
merged_data = pd.merge(data1, data2, on='Entity', how='inner')

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Entity', y='Changed Work Situation', data=merged_data, palette='Greys')
plt.title('Mudança na Situação de Trabalho por País')
plt.xlabel('País')
plt.ylabel('Mudança na Situação de Trabalho')
plt.xticks(rotation=90)
plt.show()
# Out:
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Entity', y='Changed Work Situation', data=merged_data, palette='Greys')

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Entity', y='Took Prescribed Medication', data=merged_data, color='grey', alpha=0.5, label='Took Prescribed Medication')
sns.barplot(x='Entity', y='Spent Time in Nature/Outdoors', data=merged_data, color='darkgrey', alpha=0.7, label='Spent Time in Nature/Outdoors')
plt.title('Medicação Prescrita vs. Tempo ao Ar Livre por País')
plt.xlabel('País')
plt.ylabel('Compartilhamento')
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Entity', y='Religious/Spiritual Activities', data=merged_data, palette='Greys')
plt.title('Atividades Religiosas/Espirituais por País')
plt.xlabel('País')
plt.ylabel('Atividades Religiosas/Espirituais')
plt.xticks(rotation=90)
plt.show()
# Out:
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Entity', y='Religious/Spiritual Activities', data=merged_data, palette='Greys')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv('base.csv')
data2 = pd.read_csv('antidepressants-per-capita-vs-gdp.csv')

# %%
# Análise exploratória inicial
print(data1.head())
print(data1.describe())
print(data1.info())
# Out:
#       Entity Code  Year  \
# 0     Africa  NaN  2020
# 1    Albania  ALB  2020
# 2  Argentina  ARG  2020
# 3       Asia  NaN  2020
# 4  Australia  AUS  2020
#
#    Share - Question: mh8b - Engaged in religious/spiritual activities when anxious/depressed - Answer: Yes - Gender: all - Age_group: all  \
# 0                                          63.715110
# 1                                          36.177600
# 2                                          48.529037
# 3                                          40.451416
# 4                                          19.388412
#
#    Share - Question: mh8e - Improved healthy lifestyle behaviors when anxious/depressed - Answer: Yes - Gender: all - Age_group: all  \
# 0                                          66.226456
# 1                                          67.716934
# 2                                          73.140980
# 3                                          72.909424
# 4                                          78.532410
#
# ...

# %%
# Tratar dados nulos
data1_clean = data1.dropna()

# %%
# Renomear colunas na Base de Dados Relacionados à Saúde Mental (data1)
data1.rename(columns={
    'Entity': 'País',
    'Code': 'Código País',
    'Year': 'Ano',
    'Religious/Spiritual Activities': 'Atividades Religiosas/Espirituais',
    'Improved Healthy Lifestyle': 'Estilo de Vida Saudável Aprimorado',
    'Changed Work Situation': 'Situação de Trabalho Alterada',
    'Changed Personal Relationships': 'Relacionamentos Pessoais Alterados',
    'Talked to Friends or Family': 'Conversou com Amigos ou Família',
    'Took Prescribed Medication': 'Tomou Medicamento Prescrito',
    'Spent Time in Nature/Outdoors': 'Tempo Gasto na Natureza/Ar Livre',
    'Talked to Mental Health Professional': 'Conversou com Profissional de Saúde Mental'
}, inplace=True)

# %%
# Renomear colunas na Base de Dados de Indicadores Socioeconômicos (data2)
data2.rename(columns={
    'Entity': 'País',
    'Code': 'Código País',
    'Year': 'Ano',
    'Antidepressants (Defined Daily Dose per capita)': 'Antidepressivos (Dose Diária Definida por habitante)',
    'GDP per capita (current USD)': 'PIB per capita (USD atual)',
    'Population': 'População'
}, inplace=True)

# %%
plt.figure(figsize=(12, 8))

# %%
# Tratar dados nulos
data1_clean = data1.dropna()

# %%
print(data1_clean.columns)
# Out:
# Index(['País', 'Código País', 'Ano',
#        'Share - Question: mh8b - Engaged in religious/spiritual activities when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8e - Improved healthy lifestyle behaviors when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8f - Made a change to work situation when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8g - Made a change to personal relationships when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8c - Talked to friends or family when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8d - Took prescribed medication when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
# ...

# %% [markdown]
# # Comparação entre Comportamentos em Momentos de Ansiedade/Depressão por País:
#
# # Utilize gráficos de barras para comparar diferentes comportamentos relatados em momentos de ansiedade/depressão entre países. Por exemplo, compare o percentual de pessoas que realizaram atividades religiosas/espirituais, conversaram com amigos ou familiares, tomaram medicamentos prescritos, entre outros comportamentos, para destacar variações entre países.

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='País', y='Share - Question: mh8b - Engaged in religious/spiritual activities when anxious/depressed - Answer: Yes - Gender: all - Age_group: all', data=data1_clean, palette='pink')
plt.title('Atividades Religiosas/Espirituais por País')
plt.xlabel('País')
plt.ylabel('Compartilhamento')
plt.xticks(rotation=90)
plt.show()
# Out:
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='País', y='Share - Question: mh8b - Engaged in religious/spiritual activities when anxious/depressed - Answer: Yes - Gender: all - Age_group: all', data=data1_clean, palette='pink')

# %% [markdown]
# # Tendências Temporais de Comportamentos Relacionados à Saúde Mental:
#
# # Crie gráficos de linha ou de barras ao longo do tempo (anos) para entender como os comportamentos relacionados à saúde mental mudaram ao longo dos anos em diferentes países. Isso pode revelar tendências de aumento ou diminuição desses comportamentos ao longo do tempo.

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(x='Ano', y='Share - Question: mh8b - Engaged in religious/spiritual activities when anxious/depressed - Answer: Yes - Gender: all - Age_group: all', hue='País', data=data1_clean)
plt.title('Tendências Temporais de Atividades Religiosas/Espirituais por País')
plt.xlabel('Ano')
plt.ylabel('Compartilhamento')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Correlações entre Comportamentos e Indicadores Socioeconômicos
# # Use gráficos de dispersão ou mapas de calor para investigar se há correlações entre comportamentos específicos (por exemplo, tomada de medicamentos prescritos, participação em atividades religiosas/espirituais) e indicadores socioeconômicos (PIB per capita, população, etc.). Isso pode revelar possíveis associações entre esses fatores.

# %%
print(data1_clean.columns)
# Out:
# Index(['País', 'Código País', 'Ano',
#        'Share - Question: mh8b - Engaged in religious/spiritual activities when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8e - Improved healthy lifestyle behaviors when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8f - Made a change to work situation when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8g - Made a change to personal relationships when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8c - Talked to friends or family when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
#        'Share - Question: mh8d - Took prescribed medication when anxious/depressed - Answer: Yes - Gender: all - Age_group: all',
# ...

# %%
data1_clean.rename(columns={'GDP per capita (current USD)': 'PIB per capita'}, inplace=True)
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_clean.rename(columns={'GDP per capita (current USD)': 'PIB per capita'}, inplace=True)

# %%
data1_clean.columns = ['País', 'Código País', 'Ano', 'Atividades Religiosas', 'Estilo de Vida Saudável',
                       'Mudança na Situação de Trabalho', 'Mudança nas Relações Pessoais', 'Conversou com Amigos/Família',
                       'Tomou Medicamento Prescrito', 'Tempo ao Ar Livre', 'Conversou com Profissional de Saúde Mental']

# Gráfico de dispersão com as colunas renomeadas

# %%
print(data1_clean.columns)
# Out:
# Index(['País', 'Código País', 'Ano', 'Atividades Religiosas',
#        'Estilo de Vida Saudável', 'Mudança na Situação de Trabalho',
#        'Mudança nas Relações Pessoais', 'Conversou com Amigos/Família',
#        'Tomou Medicamento Prescrito', 'Tempo ao Ar Livre',
#        'Conversou com Profissional de Saúde Mental'],
#       dtype='object')

# %%
data1_clean.rename(columns={'País': 'Country'}, inplace=True)
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_clean.rename(columns={'País': 'Country'}, inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(data1_clean.columns)
# Out:
# Index(['Country', 'Código País', 'Ano', 'Atividades Religiosas',
#        'Estilo de Vida Saudável', 'Mudança na Situação de Trabalho',
#        'Mudança nas Relações Pessoais', 'Conversou com Amigos/Família',
#        'Tomou Medicamento Prescrito', 'Tempo ao Ar Livre',
#        'Conversou com Profissional de Saúde Mental'],
#       dtype='object')

# %% [markdown]
# # Disparidades Geográficas: O gráfico de barras claramente evidencia discrepâncias significativas na proporção de pessoas que recorrem a medicamentos prescritos em diferentes países. Essas discrepâncias podem indicar variabilidades na cultura, abordagens de tratamento predominantes ou até mesmo diferenças nos sistemas de saúde mental.
#
# # Potenciais Fatores Influenciadores: Países com barras mais altas podem indicar uma maior dependência ou aceitação do tratamento por meio de medicamentos prescritos. Isso pode estar ligado a fatores como políticas de saúde mental, acesso facilitado a serviços médicos, ou mesmo a preferências culturais sobre tratamentos específicos.
#
# # Considerações para Políticas de Saúde: Essa análise pode orientar autoridades de saúde a entender melhor as preferências de tratamento em diferentes regiões. Países com altas taxas podem precisar considerar políticas de prescrição responsável, enquanto aqueles com baixas taxas podem enfatizar o acesso equitativo a tratamentos eficazes.

# %%
# Gráfico de barras para a distribuição do comportamento 'Tomou Medicamento Prescrito' por país
plt.figure(figsize=(12, 6))
sns.barplot(x='Country', y='Tomou Medicamento Prescrito', data=data1_clean)
plt.title('Distribuição do Comportamento: Tomou Medicamento Prescrito por País')
plt.xlabel('País')
plt.ylabel('Compartilhamento')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Conclusão de todos os pontos analisados no projeto:
# # No geral, ao explorar dados sobre saúde mental e indicadores econômicos em diferentes países, podemos notar variações significativas entre eles. Encontramos algumas conexões entre o dinheiro disponível e como as pessoas lidam com questões mentais. Isso sugere que o sistema econômico, como o capitalismo, pode ter um impacto na saúde mental das pessoas em escala global. No entanto, compreender totalmente essa relação complexa requer mais estudos e análises detalhadas.
